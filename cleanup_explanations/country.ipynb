# %%
import pandas as pd
import modules
import cleanup

# %% [markdown]
# # country_of_citizenship

# %%
col_list=['country_of_citizenship' , 'country_of_citzenship']
visas_df = pd.read_csv("../data/us_perm_visas.csv" , usecols=col_list)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Es lassen sich im Daten zwei Spalten finden, welche sich auf das Herkunftsland der Arbeiter beziehen.
# Es scheint als wurde für eine gewisse Dauer mit einem Schreibfehler im Datensatz gearbeitet, welcher im Nachgang behoben wurde.

# %%
modules.print_count_of_values_relation(visas_df, True, True)
# Out:
# country_of_citizenship
# 353729/374362 94%
# Filled: |███████████████████████████████████████████████---| 94.5% Rows
#
# country_of_citzenship
# 20574/374362 5%
# Filled: |██------------------------------------------------| 5.5% Rows

# %% [markdown]
# Das ausgegebene Diagramm unterstützt die Annahme. Die Spalten country_of_citizenship country_of_citzenship lassen sich überschneidungsfrei zusammenfügen.

# %%
visas_df['country_of_citizenship_cleaned'] = cleanup.clean_country_of_citizenship(visas_df)

# %%
modules.print_count_of_values_relation(visas_df, True, True)
# Out:
# country_of_citizenship
# 353729/374362 94%
# Filled: |███████████████████████████████████████████████---| 94.5% Rows
#
# country_of_citzenship
# 20574/374362 5%
# Filled: |██------------------------------------------------| 5.5% Rows
#
# country_of_citizenship_cleaned
# 374303/374362 100%
# Filled: |█████████████████████████████████████████████████-| 100.0% Rows
