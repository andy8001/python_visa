# %% [markdown]
# # Herkunftsländer der Arbeitnehmer

# %%
import cleanup
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.style.use('../own_style.mplstyle')
import numpy as np
# %matplotlib inline

# %%
#cleanup.generate_cleaned_df()

# %%
col_list = ["country_of_citizenship", "foreign_worker_info_birth_country"]
visas_df = pd.read_csv('../data/us_perm_visas_cleaned.csv', usecols=col_list)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
plt.xlabel("country_of_citizenship", labelpad=14)
visas_df['country_of_citizenship'].value_counts()[:10].plot(kind="bar", xlabel="Country of Citizenship", ylabel = "Number of Visa Applications", title = "Number of Visa Applications by Country of Citizenship", figsize = [15,5])
# Out:
# <AxesSubplot:title={'center':'Number of Visa Applications by Country of Citizenship'}, xlabel='Country of Citizenship', ylabel='Number of Visa Applications'>

# %% [markdown]
# Ergebnis: Die meisten Arbeitnehmer kommen aus den folgenden Ländern:
#
# - Indien
# - China
# - Süd Korea
#
# Die erhobenen Werte sollen noch mit den Geburtsorten der Arbeitnehmer verglichen werden.

# %%
#remove null values to improve comparability
visas_df = visas_df.dropna()


count_df1 = visas_df['country_of_citizenship'].value_counts().to_frame()
count_df2 = visas_df['foreign_worker_info_birth_country'].value_counts().to_frame()


graph_df = count_df1.join(count_df2)[:15]

graph_df
# Out:
#                 country_of_citizenship  foreign_worker_info_birth_country
# INDIA                            81076                            81334.0
# CHINA                            12988                            13757.0
# SOUTH KOREA                      11996                            12152.0
# CANADA                            5232                             2385.0
# MEXICO                            3322                             3378.0
# PHILIPPINES                       2676                             2722.0
# UNITED KINGDOM                    1829                             1640.0
# VIETNAM                           1728                             1780.0
# TAIWAN                            1514                             1616.0
# PAKISTAN                          1480                             1642.0
# FRANCE                            1322                             1245.0
# BRAZIL                            1295                             1346.0
# IRAN                              1273                             1535.0
# NEPAL                             1202                             1204.0
# VENEZUELA                         1199                             1285.0

# %%
y1_values_per_country_name = graph_df['country_of_citizenship']
y2_values_per_country_name = graph_df['foreign_worker_info_birth_country']




#plt.plot(x_count_df_country_names)
plt.figure(figsize=(10,6))

plt.plot(y1_values_per_country_name)
plt.plot(y2_values_per_country_name)
plt.xticks(rotation=90)
plt.show()

# %%
#https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/barchart.html

labels = graph_df.index
y1_values_per_country_name = graph_df['country_of_citizenship']
y2_values_per_country_name = graph_df['foreign_worker_info_birth_country']

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(20,10))
rects1 = ax.bar(x - width/2, y1_values_per_country_name, width, label='Men')
rects2 = ax.bar(x + width/2, y2_values_per_country_name, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
y2_values_per_country_name
# Out:
# INDIA             81334.0
# CHINA             13757.0
# SOUTH KOREA       12152.0
# CANADA             2385.0
# MEXICO             3378.0
# PHILIPPINES        2722.0
# UNITED KINGDOM     1640.0
# VIETNAM            1780.0
# TAIWAN             1616.0
# PAKISTAN           1642.0
# FRANCE             1245.0
# BRAZIL             1346.0
# IRAN               1535.0
# NEPAL              1204.0
# VENEZUELA          1285.0
# Name: foreign_worker_info_birth_country, dtype: float64

# %% [markdown]
# ## Anzeige als Weltkarte

# %%
# TODO: Darstellung als Weltkarte
