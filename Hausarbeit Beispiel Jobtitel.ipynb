# %% [markdown]
# ## Beispiel Jobtitel Hausarbeit

# %%
#Imports

import pandas as pd
from IPython.display import display, Markdown
import matplotlib.pyplot as plt
import numpy as np
import modules

# %% [markdown]
# Spalten laden:

# %%
col_list=['add_these_pw_job_title_9089' , 'job_info_job_title' ,
          'pw_job_title_908' , 'pw_job_title_9089', 'job_info_alt_occ_job_title']
visas_df = pd.read_csv("data/us_perm_visas.csv" , usecols=col_list)
# Out:
# C:\Users\alina\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,61,71,94,95) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Welche Zeilen haben Werte und welche Werte?

# %%
modules.print_count_of_values_relation(visas_df, True, True)
visas_df.sample(10)
# Out:
# add_these_pw_job_title_9089
# 42194/374362 11%
# Filled: |█████---------------------------------------------| 11.3% Rows
#
# job_info_alt_occ_job_title
# 147400/374362 39%
# Filled: |███████████████████-------------------------------| 39.4% Rows
#
# job_info_job_title
# 239049/374362 64%
# Filled: |███████████████████████████████-------------------| 63.9% Rows
#
# pw_job_title_908
# 150379/374362 40%
# Filled: |████████████████████------------------------------| 40.2% Rows
#
# pw_job_title_9089
# 223591/374362 60%
# Filled: |█████████████████████████████---------------------| 59.7% Rows
# C:\Users\alina\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\alina\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\alina\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\alina\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\alina\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
#        add_these_pw_job_title_9089               job_info_alt_occ_job_title  \
# 88258                          NaN                                      NaN
# 322566                         NaN             Trainee; Intern; Instructor.
# 356526                         NaN  Research Technician, Research Assistant
# 220276                         NaN                                      NaN
# 162046                         NaN                            IT Consultant
# 149123                         NaN                                      NaN
# 47703         Industrial Engineers                                      NaN
# 168528                         NaN                                Associate
# 162420                         NaN                                 See H.14
# 117415                         NaN                                      NaN
#
#                          job_info_job_title  \
# 88258                                   NaN
# 322566             Product Quality Engineer
# 356526         Quality Assurance Specialist
# 220276           Food Supplements Scientist
# 162046  Computer Systems Engineer/Architect
# 149123          MANUFACTURING ENGINEER (L3)
# 47703                                   NaN
# 168528                            Associate
# 162420                    Software Engineer
# 117415                                  NaN
#
#                          pw_job_title_908  \
# 88258                                 NaN
# 322566  Software Developers, Applications
# 356526           Natural Sciences Manager
# 220276                                NaN
# 162046                                NaN
# 149123                                NaN
# 47703                                 NaN
# 168528                                NaN
# 162420                                NaN
# 117415                                NaN
#
#                             pw_job_title_9089
# 88258   Software Developers, Systems Software
# 322566                                    NaN
# 356526                                    NaN
# 220276      Food Scientists and Technologists
# 162046              Computer Systems Analysts
# 149123                   INDUSTRIAL ENGINEERS
# 47703                    Industrial Engineers
# 168528                                Lawyers
# 162420  Software Developers, Systems Software
# 117415                   Mechanical Engineers
